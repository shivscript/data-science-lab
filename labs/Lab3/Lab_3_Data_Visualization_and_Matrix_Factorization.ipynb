# %% [markdown]
# # Lab 3: Effective Data Visualizations and Introduction to Matrix Factorization & Gradient Descent

# %% [markdown]
# In this lab, we will:
# 1. **Explore effective data visualizations** like line charts, bar charts, heat maps, and box plots to derive key insights from a dataset.
# 2. **Learn about matrix factorization** and implement it with **gradient descent**.
#
# ### Objectives:
# - Understand how to create various visualizations using Python libraries like Matplotlib and Seaborn.
# - Implement matrix factorization using gradient descent to demonstrate its application in data science.

# %% [markdown]
# ## 1. Effective Data Visualizations
#
# Data visualization helps us to understand the patterns and insights hidden in the data. Below are examples of different types of visualizations:
#
# ### Line Charts
# Used to visualize trends over time.
#
# #### Example: Sales over a year

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt  # For creating visualizations

# Define the sample data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']  # List of months
sales = [200, 220, 250, 270, 300, 310, 400, 420, 410, 390, 370, 350]  # Corresponding sales data for each month

# Create a new figure for the plot with a specified size
plt.figure(figsize=(10, 6))  # The plot will be 10 inches wide and 6 inches tall

# Plot the data on a line chart
plt.plot(
    months,             # x-axis data (months)
    sales,              # y-axis data (sales)
    marker='o',         # Adds circular markers at each data point
    color='b',          # Line color (blue)
    linestyle='-',      # Line style (solid line)
    label='Sales'       # Label for the legend
)

# Add a title to the plot
plt.title('Monthly Sales')

# Label the x-axis
plt.xlabel('Months')

# Label the y-axis
plt.ylabel('Sales')

# Add a legend to the plot
plt.legend()

# Add a grid to the plot for better readability
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ### Bar Charts
# Used to compare quantities.
#
# #### Example: Sales by product category

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Electronics', 'Fashion', 'Home', 'Books', 'Beauty']
sales = [500, 700, 400, 300, 450]

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(categories, sales, color='skyblue')
plt.title('Sales by Product Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Heat Maps
# Used to visualize correlations or density.
#
# #### Example: Correlation matrix

# %%
# Import necessary libraries
import seaborn as sns       # For creating statistical data visualizations
import numpy as np          # For numerical operations and creating random data
import pandas as pd         # For data manipulation and analysis

# Generate sample data
data = np.random.rand(10, 4)  # Creates a 10x4 matrix of random numbers between 0 and 1
columns = ['Feature1', 'Feature2', 'Feature3', 'Feature4']  # Column names for the data
df = pd.DataFrame(data, columns=columns)  # Create a DataFrame from the random data with the defined column names

# Calculate the correlation matrix
corr = df.corr()  # Computes pairwise correlation of columns in the DataFrame

# Plot the heatmap for the correlation matrix
plt.figure(figsize=(8, 6))  # Set the figure size to 8 inches wide and 6 inches tall
sns.heatmap(
    corr,                # Data to be visualized (correlation matrix)
    annot=True,          # Annotate the cells with the correlation values
    cmap='coolwarm',     # Use the 'coolwarm' colormap for a visual gradient
    fmt='.2f'            # Format the annotation to show numbers with 2 decimal places
)
plt.title('Correlation Heatmap')  # Add a title to the heatmap
plt.show()  # Display the heatmap

# %% [markdown]
# ### Box Plots
# Used to visualize data distribution and detect outliers.
#
# #### Example: Distribution of exam scores

# %%
import seaborn as sns
import numpy as np

# Sample data
exam_scores = [78, 85, 89, 92, 76, 88, 84, 79, 81, 95, 77, 82]

# Plot boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(exam_scores, color='lightgreen')
plt.title('Exam Scores Distribution')
plt.show()

# %% [markdown]
# # **Different Types of Chart**
# Different types of data visualizations, their descriptions, use cases, and example scenarios:
#
# | **Chart Type**      | **Description**                                                                                                                                                   | **When to Use**                                                                 | **Key Insights**                                                                                                                                                  | **Example Use Case**                                                                                   |
# |----------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------|
# | **Line Chart**       | Displays data points connected by a line to show trends over time or a continuous variable.                                                                       | To visualize trends or patterns over time.                                       | Identify upward or downward trends, fluctuations, or patterns in data over time.                                                             | Monthly sales growth, website traffic trends over a week.                                             |
# | **Bar Chart**        | Uses rectangular bars to represent categorical data. The height (or length) of the bars corresponds to the value of the data.                                     | To compare quantities across categories.                                        | Compare values between different categories or groups.                                                                                       | Comparing revenue from different product categories.                                                  |
# | **Heat Map**         | Represents data in a matrix format where values are depicted with varying colors, making it easy to identify patterns and correlations.                           | To show relationships or highlight concentrations in a large dataset.           | Detect correlations, clusters, or anomalies in a dataset.                                                                                   | Correlation between variables in a dataset, performance metrics for different teams.                  |
# | **Box Plot**         | Summarizes the distribution of a dataset with five summary statistics: minimum, first quartile (Q1), median, third quartile (Q3), and maximum, plus outliers.     | To understand the spread and detect outliers in a dataset.                      | Visualize data spread, detect outliers, and understand variability.                                                                          | Comparing exam scores between different classes, identifying salary ranges in different departments.   |
# | **Pie Chart**        | Represents parts of a whole as slices of a circle. Each slice's size is proportional to the data value it represents.                                              | To show proportions or percentage breakdowns.                                   | Highlight the composition of a whole or the relative size of categories.                                                                    | Market share of companies, expense distribution in a budget.                                          |
# | **Scatter Plot**     | Displays data as points in a 2D space, where each point represents values of two variables.                                                                        | To visualize relationships or correlations between two continuous variables.    | Detect correlations, clusters, or trends between two variables.                                                                             | Relationship between study time and test scores, price vs. demand analysis.                           |
# | **Histogram**        | Shows the distribution of numerical data by grouping values into bins and displaying frequencies.                                                                 | To analyze the frequency distribution of a variable.                            | Understand data spread, detect skewness, and identify peaks or gaps.                                                                         | Exam score distribution, income distribution of a population.                                         |
# | **Area Chart**       | Similar to a line chart but with the area below the line filled in.                                                                                               | To visualize cumulative trends over time.                                       | Highlight magnitude changes over time and compare between multiple categories.                                                              | Visualizing total revenue over time, population growth comparisons.                                   |
# | **Bubble Chart**     | Extends a scatter plot by adding a third dimension through the size of the bubbles.                                                                               | To show relationships with three variables.                                     | Highlight the impact of a third variable alongside two-dimensional correlations.                                                            | GDP (x-axis), population (y-axis), and GDP per capita (bubble size) for countries.                    |
# | **Violin Plot**      | Combines aspects of box plots and density plots, showing data distribution and variability for different categories.                                               | To analyze distribution and compare across categories.                          | Identify distribution shape and compare multiple distributions.                                                                             | Comparing exam score distributions across multiple subjects.                                          |
# | **Radar Chart**      | Displays multivariate data in the form of a two-dimensional chart of three or more quantitative variables represented on axes starting from the same point.         | To compare multiple variables for a single category.                            | Highlight strengths and weaknesses across multiple variables.                                                                                | Performance metrics of players in a sports team.                                                      |
# | **Waterfall Chart**  | Breaks down cumulative effects of sequentially introduced positive or negative values, often used in financial contexts.                                           | To show contribution of components to a total.                                  | Highlight how individual elements contribute to the overall value or total change.                                                          | Showing profit breakdown, revenue growth analysis.                                                    |
# | **Stacked Bar Chart**| Extends a bar chart by stacking categories to show part-to-whole relationships for each bar.                                                                     | To compare totals and their components across categories.                       | Understand both the total size of a category and the composition of its subcategories.                                                      | Sales of product categories across multiple regions.                                                  |
#
# Each of these charts provides unique insights, enabling better decision-making through effective data visualization.

# %% [markdown]
# # **Chart Drawing Syntax**
#
# | **Chart Type**      | **Library** | **Syntax**                                                                                      |
# |----------------------|-------------|------------------------------------------------------------------------------------------------|
# | **Line Chart**       | Matplotlib  | `plt.plot(x, y, label='label')` <br> `plt.legend(), plt.grid(), plt.show()`                   |
# |                      | Seaborn     | `sns.lineplot(x='column_x', y='column_y', data=df)`                                            |
# | **Bar Chart**        | Matplotlib  | `plt.bar(categories, values)` <br> `plt.show()`                                               |
# |                      | Seaborn     | `sns.barplot(x='column_x', y='column_y', data=df)`                                            |
# | **Heat Map**         | Seaborn     | `sns.heatmap(data, annot=True, cmap='coolwarm')`                                              |
# | **Box Plot**         | Matplotlib  | `plt.boxplot(data)` <br> `plt.show()`                                                         |
# |                      | Seaborn     | `sns.boxplot(x='column_x', y='column_y', data=df)`                                            |
# | **Pie Chart**        | Matplotlib  | `plt.pie(values, labels=categories, autopct='%1.1f%%')` <br> `plt.show()`                    |
# | **Scatter Plot**     | Matplotlib  | `plt.scatter(x, y)` <br> `plt.show()`                                                        |
# |                      | Seaborn     | `sns.scatterplot(x='column_x', y='column_y', data=df)`                                        |
# | **Histogram**        | Matplotlib  | `plt.hist(data, bins=10)` <br> `plt.show()`                                                  |
# |                      | Seaborn     | `sns.histplot(data, bins=10)`                                                                |
# | **Area Chart**       | Matplotlib  | `plt.fill_between(x, y, alpha=0.5)` <br> `plt.plot(x, y)` <br> `plt.show()`                  |
# | **Bubble Chart**     | Matplotlib  | `plt.scatter(x, y, s=bubble_size)` <br> `plt.show()`                                         |
# | **Violin Plot**      | Seaborn     | `sns.violinplot(x='column_x', y='column_y', data=df)`                                         |
# | **Radar Chart**      | Matplotlib  | `plt.plot(angles, values, 'o-', label='label')` <br> `plt.fill(angles, values, alpha=0.25)` <br> `plt.show()` |
# | **Waterfall Chart**  | Matplotlib  | Use cumulative sum logic with `plt.bar()`                                                    |
# | **Stacked Bar Chart**| Matplotlib  | `plt.bar(x, category1)` <br> `plt.bar(x, category2, bottom=category1)` <br> `plt.show()`     |
# |                      | Seaborn     | `sns.barplot(x='column_x', y='column_y', hue='category', data=df)`                           |

# %% [markdown]
# ## 2. Matrix Factorization and Gradient Descent
#
# ### Matrix factorization
# Matrix factorization is a mathematical technique that breaks down a large matrix into smaller matrices that, when multiplied, approximate the original. It is widely used in recommendation systems, data compression, and dimensionality reduction.
#
# Matrix factorization is a technique widely used in recommendation systems to predict user-item relationships.
#
# #### Real-World Example
# Netflix Recommendation System: Netflix predicts a user's preference for movies they haven't rated yet. If a user has rated "Inception" and "The Dark Knight" highly, matrix factorization can help predict that the user might also like other movies by Christopher Nolan, such as "Interstellar."
#
# ### Gradient descent
# Gradient descent is an optimization algorithm used to minimize a loss function by iteratively adjusting parameters. It is widely used in machine learning, deep learning, and optimization problems.
#
# #### Real-World Example
# Gradient descent is like perfecting a pancake recipe based on feedback. You start with a guess for the amounts of ingredients (flour, milk, eggs, sugar), make pancakes, and get feedback (e.g., "too sweet, too thick"). You then adjust the ingredients slightly, reducing sugar or flour, and try again. Each adjustment reduces the error (how far the pancake is from perfect). Over time, with small, repeated changes, you get closer to the ideal recipe. Similarly, gradient descent adjusts parameters in a model step-by-step to minimize errors and improve predictions.

# %% [markdown]
# ### **Types of Gradient Descent**
#
# 1. **Batch Gradient Descent**
#    - Uses the entire dataset to compute the gradient at each step.
#    - Pros: More stable updates, less noise in gradient calculations.
#    - Cons: Computationally expensive for large datasets.
#
# 2. **Stochastic Gradient Descent (SGD)**
#    - Updates parameters for each data point individually.
#    - Pros: Faster updates, suitable for online learning.
#    - Cons: Noisy updates, which can lead to fluctuating convergence.
#
# 3. **Mini-batch Gradient Descent**
#    - Combines Batch Gradient Descent and SGD by using a small subset (mini-batch) of the data for each update.
#    - Pros: Balances speed and stability, reduces noise compared to SGD.
#    - Cons: Still computationally expensive for very large datasets.

# %% [markdown]
# ## Matrix Factorization with Gradient Descent Example in Python
#
# ### Problem:
# We have a small dataset where users rate movies. Some ratings are missing, and we want to predict them.
#
# **User-Movie Rating Matrix**:
#
# |        | Movie 1 | Movie 2 | Movie 3 |
# |--------|---------|---------|---------|
# | User 1 |    5    |    3    |    ?    |
# | User 2 |    4    |    ?    |    2    |
# | User 3 |    ?    |    1    |    3    |
#
# The goal is to predict the missing ratings (denoted as "?").
#
# ---

# %%
import numpy as np

# Small user-movie rating matrix (0 indicates missing ratings)
ratings = np.array([  # Create a 3x3 matrix of ratings where 0 represents missing ratings
    [5, 3, 0],  # User 1's ratings for Movie 1 and Movie 2, missing for Movie 3
    [4, 0, 2],  # User 2's ratings for Movie 1 and Movie 3, missing for Movie 2
    [0, 1, 3]   # User 3's ratings for Movie 2 and Movie 3, missing for Movie 1
])

# Initialize user (P) and movie (Q) matrices with random values
num_users, num_movies = ratings.shape  # Get the dimensions of the ratings matrix (3 users, 3 movies)
num_features = 2  # Number of latent features to be learned (used to represent users and movies)
P = np.random.rand(num_users, num_features)  # Randomly initialize the user-feature matrix (P)
Q = np.random.rand(num_movies, num_features)  # Randomly initialize the movie-feature matrix (Q)

# Transpose Q for easier calculations
Q = Q.T  # Transpose the Q matrix to make matrix multiplication easier

# Training parameters
steps = 2000  # Number of iterations (epochs) for the gradient descent
learning_rate = 0.01  # The step size for updating the features in each iteration
regularization = 0.02  # Regularization term to avoid overfitting

# Matrix factorization function
def matrix_factorization(R, P, Q, steps, learning_rate, reg):
    for step in range(steps):  # Loop through the number of iterations
        for i in range(len(R)):  # Loop through each user (row in the ratings matrix)
            for j in range(len(R[i])):  # Loop through each movie (column in the ratings matrix)
                if R[i][j] > 0:  # Only update for known ratings (non-zero entries in the ratings matrix)
                    # Error between the actual and predicted ratings
                    error = R[i][j] - np.dot(P[i, :], Q[:, j])  # Compute the prediction error
                    # Update user and movie features using gradient descent
                    P[i, :] += learning_rate * (error * Q[:, j] - reg * P[i, :])  # Update user feature vector (P)
                    Q[:, j] += learning_rate * (error * P[i, :] - reg * Q[:, j])  # Update movie feature vector (Q)
    return P, Q  # Return the updated user and movie matrices

# Perform matrix factorization
P, Q = matrix_factorization(ratings, P, Q, steps, learning_rate, regularization)  # Train the matrices P and Q

# Reconstruct the full rating matrix (predicted ratings)
predicted_ratings = np.dot(P, Q)  # Multiply the user matrix (P) and movie matrix (Q) to get the predicted ratings

print("Original Ratings Matrix:")  # Print the original ratings matrix
print(ratings)  # Display the original matrix

print("\nPredicted Ratings Matrix:")  # Print the predicted ratings matrix
print(np.round(predicted_ratings, 2))  # Round the predicted ratings to 2 decimal places and display
# Out:
# Original Ratings Matrix:
# [[5 3 0]
#  [4 0 2]
#  [0 1 3]]
#
# Predicted Ratings Matrix:
# [[4.98 2.97 2.09]
#  [3.97 2.14 2.01]
#  [3.4  1.   2.96]]

# %% [markdown]
# ## Simple Analogy
# ### Matrix Factorization:
# Breaking a cake recipe into ingredients (flour, sugar, etc.) to recreate similar cakes.
#
# ### Gradient Descent:
# Tasting the cake, realizing it’s too sweet, and adjusting the recipe little by little until it’s perfect.

# %% [markdown]
# # Data Visualization Practice Questions
#
# ## 1. Line Chart Practice Question
# **Question:**
# You are given a dataset of monthly rainfall (in mm) for your city over the past year. Create a line chart that shows the rainfall trend for the year. Label the axes and provide a title.
#
# **Dataset**
# - January: 45mm
# - February: 38mm
# - March: 60mm
# - April: 70mm
# - May: 75mm
# - June: 80mm
# - July: 90mm
# - August: 85mm
# - September: 72mm
# - October: 50mm
# - November: 40mm
# - December: 30mm
#
# **Instructions:**
# - Label the x-axis as "Month" and the y-axis as "Rainfall (mm)".
# - Title the chart as "Monthly Rainfall Trend Created by [Your Name]".
#
# ---
#
# ## 2. Bar Chart Practice Question
# **Question:**
# You are given data showing the number of books read by students in your class during the past month. Create a bar chart to compare the number of books read by each student.
#
# **Dataset**
# - Student A: 5 books
# - Student B: 7 books
# - [Your Name]: 3 books
# - Student D: 8 books
# - Student E: 6 books
#
# **Instructions:**
# - Label the x-axis with the student names and the y-axis with the number of books.
# - Title the chart as "Books Read by Students".
#
# ---
#
# ## 3. Scatter Plot Practice Question
#
# **Question:**
# You are given data showing the relationship between study hours and grade scores for 5 students. Create a scatter plot to visualize how study time and grades are related.
#
# **Dataset**
# | Student     | Study Hours | Grade Score |
# |-------------|-------------|-------------|
# | Student 1   | 5           | 75          |
# | Student 2   | 3           | 65          |
# | Student 3   | 8           | 85          |
# | [Your Name] | 2           | 60          |
# | Student 5   | 6           | 80          |
#
# **Instructions:**
# - Create a scatter plot with "Study Hours" on the x-axis and "Grade Score" on the y-axis.
# - Label the axes and add a title to the plot.
# - Optionally, you can add a regression line to visualize the trend.
#
# ---
#
# ## 4. Box Plot Practice Question
# **Question:**
# You have the exam scores of 10 students in your class. Create a box plot to show the distribution of exam scores.
#
# **Dataset**
# - 50, 65, 70, 85, 60, 75, 80, 90, 55, 70.
#
# **Instructions:**
# - Create a box plot to show the spread of the exam scores.
# - Label the x-axis as "Exam Scores" and provide a title such as "Distribution of Exam Scores Created by [Your Name]".
#
# ---
#
# ## 5. Scatter Plot Practice Question
# **Question:**
# You are given data showing the heights (in cm) and weights (in kg) of your friends. Create a scatter plot to show how weight and height are related.
#
# **Dataset**
# | Friend   | Height (cm) | Weight (kg) |
# |----------|-------------|-------------|
# | Friend 1 | 160         | 55          |
# | Friend 2 | 170         | 62          |
# | Friend 3 | 175         | 70          |
# | Friend 4 | 165         | 58          |
# | [Your Name] | 180         | 80          |
#
# **Instructions:**
# - Plot height on the x-axis and weight on the y-axis.
# - Label the axes and title the chart as "Height vs Weight".
#
# ---
#
# ## 6. Heatmap Visualization Practice Question
#
# **Question:**
# You are given data showing the scores of students across different subjects. Create a heatmap to visualize the relationship between students and their scores in each subject.
#
# **Dataset:**
#
# | Student   | Math | English | Science | History | Art |
# |-----------|------|---------|---------|---------|-----|
# | Student 1 | 90   | 80      | 85      | 75      | 88  |
# | Student 2 | 78   | 85      | 92      | 70      | 80  |
# | Student 3 | 95   | 92      | 89      | 80      | 90  |
# | [Your Name] | 80   | 78      | 85      | 75      | 82  |
# | Student 5 | 88   | 80      | 90      | 85      | 91  |
#
# **Instructions:**
# - Create a heatmap with students on the y-axis and subjects on the x-axis.
# - Use the `seaborn.heatmap()` function to visualize the scores.
# - Customize the color scale to represent score intensity.
# - Label the axes and add a title to the plot.
